# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Audio

# %%
df = pd.read_excel('Newcoarsecrackles.xlsx',header=None)

# %%
df
# Out:
#               0         1         2         3         4         5         6   \
# 0       0.000000 -0.001923  0.001129  0.004120 -0.002411 -0.000946  0.003540
# 1       0.000023 -0.001953  0.001038  0.004059 -0.002380 -0.000977  0.003601
# 2       0.000045 -0.001984  0.000977  0.003998 -0.002350 -0.000977  0.003662
# 3       0.000068 -0.002045  0.000916  0.003998 -0.002319 -0.000977  0.003723
# 4       0.000091 -0.002075  0.000885  0.003967 -0.002319 -0.000977  0.003693
# ...          ...       ...       ...       ...       ...       ...       ...
# 108923  2.469909 -0.002808 -0.000214 -0.000519 -0.001343  0.000458 -0.000214
# 108924  2.469932 -0.002930 -0.000458 -0.000397 -0.001068  0.000610  0.000031
# 108925  2.469955 -0.003082 -0.000732 -0.000275 -0.000793  0.000702  0.000305
# 108926  2.469977 -0.003143 -0.001007 -0.000183 -0.000519  0.000824  0.000549
# 108927  2.470000 -0.003265 -0.001251 -0.000122 -0.000244  0.000946  0.000793
#
# ...

# %%
plt.plot(df.iloc[:,1])

# %%
wav_array = df.iloc[:,1]

Audio(data=wav_array,rate=10000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
